# %%
# -*- coding: utf-8 -*-
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
#zhfont1 = mpl.font_manager.FontProperties(fname='C:\\Windows\\Fonts\\simsun.ttc',size=12)

# %%
import numpy as np

# %%
# df_sha = pd.read_csv('sha/sha_processed_data.csv')
df_fen = pd.read_csv('fen/fen_processed_data.csv')
cols = list(df_fen.columns)
# t_sha = np.array([5*i/60 for i in range(df_sha.shape[0])])
t_fen = np.array([5*i/60 for i in range(df_fen.shape[0])])

# %%
df_fen['t_h'] = t_fen/60
df_fen['t_m'] = t_fen
df_fen
# Out:
#         s_200  s_400  m_200  m_400    s_c    m_c         t_h          t_m
# 0       0.010  0.000  0.010  0.000  0.000  0.000    0.000000     0.000000
# 1       0.010  0.000  0.010  0.000  0.000  0.000    0.001389     0.083333
# 2       0.010  0.000  0.010  0.000  0.000  0.000    0.002778     0.166667
# 3       0.010  0.000  0.010  0.000  0.000  0.000    0.004167     0.250000
# 4       0.010  0.000  0.010  0.000  0.000  0.000    0.005556     0.333333
# 5       0.010  0.000  0.010  0.000  0.000  0.000    0.006944     0.416667
# 6       0.010  0.000  0.010  0.000  0.000  0.000    0.008333     0.500000
# 7       0.010  0.000  0.010  0.000  0.000  0.000    0.009722     0.583333
# 8       0.010  0.000  0.010  0.000  0.000  0.000    0.011111     0.666667
# 9       0.010  0.000  0.010  0.000  0.000  0.000    0.012500     0.750000
# 10      0.010  0.000  0.010  0.000  0.000  0.000    0.013889     0.833333
# 11      0.010  0.000  0.010  0.000  0.000  0.000    0.015278     0.916667
# 12      0.010  0.000  0.010  0.000  0.000  0.000    0.016667     1.000000
# 13      0.010  0.000  0.010  0.000  0.000  0.000    0.018056     1.083333
# 14      0.010  0.000  0.010  0.000  0.000  0.000    0.019444     1.166667
# 15      0.010  0.000  0.010  0.000  0.000  0.000    0.020833     1.250000
# 16      0.010  0.000  0.010  0.000  0.000  0.000    0.022222     1.333333
# 17      0.010  0.000  0.010  0.000  0.000  0.000    0.023611     1.416667
# 18      0.010  0.000  0.010  0.000  0.000  0.000    0.025000     1.500000
# 19      0.140  0.000  0.010  0.000  0.000  0.000    0.026389     1.583333
# 20      0.200  0.000  0.010  0.000  0.000  0.000    0.027778     1.666667
# 21      0.220  0.000  0.010  0.000  0.000  0.000    0.029167     1.750000
# 22      0.220  0.000  0.010  0.000  0.000  0.000    0.030556     1.833333
# 23      0.230  0.000  0.010  0.000  0.000  0.000    0.031944     1.916667
# 24      0.230  0.000  0.010  0.000  0.000  0.000    0.033333     2.000000
# 25      0.230  0.000  0.010  0.000  0.000  0.000    0.034722     2.083333
# 26      0.230  0.000  0.010  0.000  0.000  0.000    0.036111     2.166667
# 27      0.230  0.000  0.010  0.000  0.000  0.000    0.037500     2.250000
# 28      0.240  0.000  0.010  0.000  0.000  0.000    0.038889     2.333333
# 29      0.240  0.000  0.010  0.000  0.000  0.000    0.040278     2.416667
# ...       ...    ...    ...    ...    ...    ...         ...          ...
# 118344  0.292  1.159  0.425  0.525  2.088  1.782  164.366667  9862.000000
# 118345  0.292  1.159  0.425  0.526  2.088  1.782  164.368056  9862.083333
# 118346  0.292  1.159  0.425  0.526  2.088  1.782  164.369444  9862.166667
# 118347  0.292  1.159  0.425  0.526  2.088  1.782  164.370833  9862.250000
# 118348  0.292  1.159  0.425  0.526  2.088  1.782  164.372222  9862.333333
# 118349  0.292  1.159  0.425  0.526  2.088  1.783  164.373611  9862.416667
# 118350  0.292  1.159  0.424  0.526  2.088  1.782  164.375000  9862.500000
# 118351  0.292  1.159  0.425  0.526  2.088  1.782  164.376389  9862.583333
# 118352  0.292  1.159  0.425  0.526  2.088  1.782  164.377778  9862.666667
# 118353  0.292  1.159  0.425  0.526  2.088  1.782  164.379167  9862.750000
# 118354  0.292  1.159  0.425  0.526  2.088  1.782  164.380556  9862.833333
# 118355  0.292  1.159  0.425  0.526  2.088  1.782  164.381944  9862.916667
# 118356  0.292  1.159  0.425  0.526  2.088  1.782  164.383333  9863.000000
# 118357  0.292  1.159  0.425  0.526  2.088  1.782  164.384722  9863.083333
# 118358  0.292  1.159  0.425  0.526  2.088  1.782  164.386111  9863.166667
# 118359  0.292  1.159  0.425  0.526  2.088  1.782  164.387500  9863.250000
# 118360  0.292  1.159  0.425  0.526  2.088  1.782  164.388889  9863.333333
# 118361  0.292  1.159  0.425  0.526  2.088  1.782  164.390278  9863.416667
# 118362  0.292  1.159  0.424  0.526  2.088  1.782  164.391667  9863.500000
# 118363  0.292  1.159  0.425  0.526  2.088  1.782  164.393056  9863.583333
# 118364  0.292  1.159  0.425  0.526  2.088  1.782  164.394444  9863.666667
# 118365  0.292  1.159  0.425  0.526  2.088  1.782  164.395833  9863.750000
# 118366  0.292  1.159  0.425  0.526  2.088  1.782  164.397222  9863.833333
# 118367  0.292  1.159  0.425  0.526  2.088  1.782  164.398611  9863.916667
# 118368  0.292  1.159  0.425  0.526  2.088  1.782  164.400000  9864.000000
# 118369  0.292  1.159  0.425  0.526  2.088  1.783  164.401389  9864.083333
# 118370  0.292  1.159  0.425  0.526  2.088  1.783  164.402778  9864.166667
# 118371  0.292  1.159  0.425  0.526  2.088  1.782  164.404167  9864.250000
# 118372  0.291  1.159  0.424  0.526  2.088  1.782  164.405556  9864.333333
# 118373  0.292  1.159  0.425  0.526  2.088  1.782  164.406944  9864.416667
#
# [118374 rows x 8 columns]

# %%
#fen_s_200
i = 0
fig, ax = plt.subplots(figsize=(8,4), dpi=300)
ax.plot(df_fen['t_m'], df_fen[cols[i]])
ax.invert_yaxis()
ax.set_xlabel('time / min', fontsize=12)
ax.set_ylabel('settlement / mm', fontsize=12)
fig.tight_layout()
ax.set_title('silt-{0}'.format(cols[i]), fontsize=14)
# 插入
inset_ax = fig.add_axes([0.5, 0.5, 0.35, 0.35]) # X, Y, 宽度，高度
inset_ax.plot(df_fen['t_m'], df_fen[cols[i]])
inset_ax.set_title('zoom near origin')
# 设置坐标轴范围
inset_ax.set_xlim(0, 10)
inset_ax.set_ylim(0.3, 0)
inset_ax.set_xlabel('time / min',fontsize=12)
inset_ax.set_ylabel('settlement / mm', fontsize=12)
fig.savefig('figs/silt-{0}'.format(cols[i])+'.svg')

# %%
#fen_s_400
i=1
fig, ax = plt.subplots(figsize=(8,4), dpi=300)
ax.plot(df_fen['t_m'], df_fen[cols[i]])
# ax.set_ylim(0.75, 0)
ax.invert_yaxis()
ax.set_xlabel('time / min', fontsize=12)
ax.set_ylabel('settlement / mm', fontsize=12)
fig.tight_layout()
ax.set_title('silt-{0}'.format(cols[i]), fontsize=14)
# 插入
inset_ax = fig.add_axes([0.5, 0.5, 0.35, 0.35]) # X, Y, 宽度，高度
inset_ax.plot(df_fen['t_m'], df_fen[cols[i]])
inset_ax.set_title('zoom near origin')
# 设置坐标轴范围
inset_ax.set_xlim(0, 10)
inset_ax.set_ylim(1.2, -0.2)
inset_ax.set_xlabel('time / min',fontsize=12)
inset_ax.set_ylabel('settlement / mm', fontsize=12)
fig.savefig('figs/silt-{0}'.format(cols[i])+'.svg')

# %%
#silt_m_200
i=2
fig, ax = plt.subplots(figsize=(8,4), dpi=300)
ax.plot(df_fen['t_m'], df_fen[cols[i]])
ax.set_ylim(0.5, 0)
ax.set_xlabel('time / min', fontsize=12)
ax.set_ylabel('settlement / mm', fontsize=12)
fig.tight_layout()
ax.set_title('silt-{0}'.format(cols[i]), fontsize=14)
# 插入
inset_ax = fig.add_axes([0.5, 0.5, 0.35, 0.35]) # X, Y, 宽度，高度
inset_ax.plot(df_fen['t_m'], df_fen[cols[i]])
inset_ax.set_title('zoom near origin')
# 设置坐标轴范围
inset_ax.set_xlim(0, 10)
inset_ax.set_ylim(0.5, -0.2)
inset_ax.set_xlabel('time / min',fontsize=12)
inset_ax.set_ylabel('settlement / mm', fontsize=12)
fig.savefig('figs/silt-{0}'.format(cols[i])+'.svg')

# %%
#silt_m_400
i=3
fig, ax = plt.subplots(figsize=(8,4), dpi=300)
ax.plot(df_fen['t_m'], df_fen[cols[i]])
ax.set_ylim(0.65, 0)
ax.set_xlabel('time / min', fontsize=12)
ax.set_ylabel('settlement / mm', fontsize=12)
fig.tight_layout()
ax.set_title('silt-{0}'.format(cols[i]), fontsize=14)
# 插入
inset_ax = fig.add_axes([0.5, 0.5, 0.35, 0.35]) # X, Y, 宽度，高度
inset_ax.plot(df_fen['t_m'], df_fen[cols[i]])
inset_ax.set_title('zoom near origin')
# 设置坐标轴范围
inset_ax.set_xlim(0, 10)
inset_ax.set_ylim(0.6, -0.1)
inset_ax.set_xlabel('time / min',fontsize=12)
inset_ax.set_ylabel('settlement / mm', fontsize=12)
fig.savefig('figs/silt-{0}'.format(cols[i])+'.svg')

# %%
#fen_s_c
i=4
fig, ax = plt.subplots(figsize=(8,4), dpi=300)
ax.plot(df_fen['t_m'], df_fen[cols[i]])
ax.invert_yaxis()
# ax.set_ylim(2, 0)
ax.set_xlabel('time / min', fontsize=12)
ax.set_ylabel('settlement / mm', fontsize=12)
fig.tight_layout()
ax.set_title('silt-{0}'.format(cols[i]), fontsize=14)
# 插入
inset_ax = fig.add_axes([0.2, 0.28, 0.35, 0.35]) # X, Y, 宽度，高度
inset_ax.plot(df_fen['t_m'], df_fen[cols[i]])
inset_ax.set_title('zoom near origin')
# 设置坐标轴范围
inset_ax.set_xlim(0, 10)
inset_ax.set_ylim(0.12, -0.02)
inset_ax.set_xlabel('time / min',fontsize=12)
inset_ax.set_ylabel('settlement / mm', fontsize=12)
fig.savefig('figs/silt-{0}'.format(cols[i])+'.svg')

# %%
#silt_m_c
i=5
fig, ax = plt.subplots(figsize=(8,4), dpi=300)
ax.plot(df_fen['t_m'], df_fen[cols[i]])
ax.invert_yaxis()
# ax.set_ylim(2, 0)
ax.set_xlabel('time / min', fontsize=12)
ax.set_ylabel('settlement / mm', fontsize=12)
fig.tight_layout()
ax.set_title('silt-{0}'.format(cols[i]), fontsize=14)
# 插入
inset_ax = fig.add_axes([0.2, 0.28, 0.35, 0.35]) # X, Y, 宽度，高度
inset_ax.plot(df_fen['t_m'], df_fen[cols[i]])
inset_ax.set_title('zoom near origin')
# 设置坐标轴范围
inset_ax.set_xlim(0, 10)
inset_ax.set_ylim(0.3, -0.02)
inset_ax.set_xlabel('time / min',fontsize=12)
inset_ax.set_ylabel('settlement / mm', fontsize=12)
fig.savefig('figs/silt-{0}'.format(cols[i])+'.svg')

# %%
#silt_m_c
fig, ax = plt.subplots(figsize=(10,4), dpi=300)
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width*0.8, box.height])

for i in range(6):
    ax.plot(df_fen['t_m'], df_fen[cols[i]], label=cols[i])
# ax.invert_yaxis()
ax.set_ylim(3.5, 0)
ax.set_xlabel('time / min', fontsize=12)
ax.set_ylabel('settlement / mm', fontsize=12)
# fig.tight_layout()
ax.set_title('consolidation of calcareous silt', fontsize=14)
ax.legend(bbox_to_anchor=(1.2, 1), borderaxespad=0.)
# 插入
inset_ax = fig.add_axes([0.2, 0.25, 0.35, 0.3]) # X, Y, 宽度，高度
for i in range(6):
    inset_ax.plot(df_fen['t_m'], df_fen[cols[i]])
inset_ax.set_title('zoom near origin', fontsize=11)
# 设置坐标轴范围
inset_ax.set_xlim(0, 10)
inset_ax.set_ylim(1.2, -0.2)
inset_ax.set_xlabel('time / min',fontsize=11)
inset_ax.set_ylabel('settlement / mm', fontsize=11)
fig.savefig('figs/silt.svg', bbox_inches='tight')
