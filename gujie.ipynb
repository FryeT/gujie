# %%
# -*- coding: utf-8 -*-
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
zhfont1 = mpl.font_manager.FontProperties(fname='C:\\Windows\\Fonts\\simsun.ttc',size=12)

# %%
df_sha = pd.read_csv('sha/processed_data.csv')
df_fen = pd.read_csv('fen/processed_data.csv')
cols = list(df_sha.columns)
t_sha = [5*i/60 for i in range(df_sha.shape[0])]
t_fen = [5*i/60 for i in range(df_fen.shape[0])]

# %%
plt.figure(figsize=(16,9),dpi=300)
for nrow in range(3):
    for ncol in range(2):
        plot_num = 2*nrow+ncol+1
        plt.subplot(3,2,plot_num)
        plt.plot(t_sha,df_sha[cols[plot_num-1]])
        plt.gca().invert_yaxis()
        plt.title(u'珊瑚砂-' + cols[plot_num-1],fontproperties=zhfont1)

# %%
plt.figure(figsize=(16,9),dpi=300)
for nrow in range(3):
    for ncol in range(2):
        plot_num = 2*nrow+ncol+1
        plt.subplot(3,2,plot_num)
        plt.plot(t_fen,df_fen[cols[plot_num-1]])
        plt.gca().invert_yaxis()
        plt.title(u'珊瑚粉-' + cols[plot_num-1], fontproperties=zhfont1)

# %%
df_sha.ix[0]
# Out:
# s_200    0.016
# s_400    0.016
# m_200    0.077
# m_400   -0.033
# s_c      0.048
# m_c      0.001
# Name: 0, dtype: float64

# %%
df_sha2=df_sha-df_sha.ix[0]

# %%
df_sha2.plot()

# %%
df_fen2 = df_fen-df_fen.ix[0]
df_fen2.plot()
